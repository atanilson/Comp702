# %% [markdown]
# <a href="https://colab.research.google.com/github/atanilson/Comp702/blob/main/COMP702_Aplied_model2_Costuom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Geospacial Data Processing Tools
#
# * Google Earth Engine, Python Earth Engine Application
# * GeoPanda Geospacial Analysis
# * Rasterio
# * Foliom

# %%
# %%capture
# !pip -q install --upgrade folium
# !apt install libspatialindex-dev
# !pip -q install rtree
# !pip -q install geopandas
# !pip -q install geojson
# !pip -q install geemap==0.17.3
# !pip -q uninstall tornado -y
# !yes | pip install tornado==5.1.0
# !pip -q install rasterio
# !pip -q install tqdm
# !pip -q install eeconvert

# %%
# Standard imports
import os
from tqdm.auto import tqdm
import requests
import json

import pandas as pd
import numpy as np
from PIL import Image

# Geospacial processing packages
import geopandas as gpd
import geojson

import shapely
import rasterio as rio
from rasterio.plot import show
import rasterio.mask
from shapely.geometry import box

# Mapping and plotting libraries
import matplotlib.pyplot as plt
import matplotlib.colors as cl
import ee
import eeconvert as eec
import geemap
import geemap.eefolium as emap
import folium

# Model
import torch
from torchvision import datasets, models, transforms

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Authenticating in Google Earth Engine

# %%
ee.Authenticate()
#ee.Initialize(project="atanilson-sgac")
ee.Initialize(project="ee-atanilsont")

# %% [markdown]
# # Downloading boundaries of the country of interest
#
# Using geoBoundaries API
#
# https://www.geoboundaries.org/api.html#api
#
# END Point - https://www.geoboundaries.org/api/current/[RELEASE-TYPE]/[3-LETTER-ISO-CODE]/[BOUNDARY-TYPE]/

# %%
# Area of interest and admin level
AOI = "GBR"
ADM = "ADM3"

# Query geoBoundaries
url = f"https://www.geoboundaries.org/api/current/gbOpen/{AOI}/{ADM}"

r = requests.get(url)
download_path = r.json()["gjDownloadURL"]

# Save the results as a GeoJSON
filename = "geoboundary.geojson"
geoboundary = requests.get(download_path).json()
with open(filename, "w") as file:
    geojson.dump(geoboundary, file)

# %%
# Read data using GeoPandas
geoboundary = gpd.read_file(filename)
print("Data dimensions: {}".format(geoboundary.shape))
# Out:
# Data dimensions: (216, 6)

# %% [markdown]
# Usning an example district, e.g. Kreis Borken

# %%
shape_name = "Liverpool"
#shape_name = "Lincolnshire"
#shape_name = "North Yorkshire"
#shape_name = "Norfolk" #2025-07-11  85%

fig, ax = plt.subplots(1, figsize=(10,10))
geoboundary[geoboundary.shapeName == shape_name].plot("shapeName", legend=True, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Google Earth Engine

# %%
def generate_image(
        region,
        product="COPERNICUS/S2_SR_HARMONIZED",
        min_date="2024-01-01",
        max_date="2025-01-01",
        range_min=0, #Deleete to invetigete
        range_max=2000, #Same
        cloud_pct=70
        ):

    image = ee.ImageCollection(product)\
            .filterBounds(region)\
            .filterDate(str(min_date), str(max_date))\
            .filter(ee.Filter.lt("CLOUDY_PIXEL_PERCENTAGE", cloud_pct))\
            .median()

    # Get RGB image
    image = image.visualize(bands=["B4","B3","B1"], min=range_min, max=range_max)

    return image.clip(region)

# %%
def generate_image_from_date(
        region,
        specific_date="2024-06-12",
        product="COPERNICUS/S2_SR_HARMONIZED",
        range_min=0,
        range_max=2000,
        cloud_pct=100
    ):
    # Convert to start and end of specific day
    start_date = ee.Date(specific_date)
    end_date = start_date.advance(1, 'day')

    # Filter for the specific day
    image = ee.ImageCollection(product)\
            .filterBounds(region)\
            .filterDate(start_date, end_date)\
            .filter(ee.Filter.lt("CLOUDY_PIXEL_PERCENTAGE", cloud_pct))\
            .first()  # Get the first available image on that day

    # Get RGB image
    image = ee.Image(image).visualize(bands=["B4", "B3", "B1"], min=range_min, max=range_max)

    return image.clip(region)

# %%
## Generating and VIsualizing

# %%
# Getting the shape
region = geoboundary.loc[geoboundary.shapeName == shape_name]
centroid = region.iloc[0].geometry.centroid.coords[0]
region = eec.gdfToFc(region) #geodataframe to feature collection

# Generate RGB image using GEE
image = generate_image(
    region,
    product="COPERNICUS/S2_SR_HARMONIZED",# Sentinel-2A
    min_date = "2024-07-12", # Get all images within
    max_date="2025-07-07", # The yea
    cloud_pct=70, # Fil0er our image with cloud cover >= 10%
)

image1 = generate_image_from_date(
    region,
    specific_date="2025-07-12",
    product="COPERNICUS/S2_SR_HARMONIZED",
    range_min=0,
    range_max=2000,
    cloud_pct=50
)

#Visualize map
Map = emap.Map(center=[centroid[1], centroid[0]], zoom=10)
Map.addLayer(region, {}, "Linconshire")
Map.addLayer(image1, {}, "Sentinel2")
Map.addLayerControl()
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c051206dae59c3e983dd16226fcb0ff8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c051206dae59c3e983dd16226fcb0ff8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c051206dae59c3e983dd16226fcb0ff8 = L.map(
#                 &quot;map_c051206dae59c3e983dd16226fcb0ff8&quot;,
#                 {
#                     center: [53.40433052645946, -2.9162212573496853],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: true,
#   &quot;pluginLatlngpopup&quot;: true,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: false,
#   &quot;DrawExport&quot;: true,
#   &quot;pluginMinimap&quot;: false,
#   &quot;pluginLayercontrol&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abc53a97f953e158043ba853b55a5f9a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_abc53a97f953e158043ba853b55a5f9a.addTo(map_c051206dae59c3e983dd16226fcb0ff8);
#
#
#             var tile_layer_d08653ac6ffbaf06bdd8676c20eac701 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d08653ac6ffbaf06bdd8676c20eac701.addTo(map_c051206dae59c3e983dd16226fcb0ff8);
#
#
#                 var lat_lng_popup_346d1a6d2543ff78a4245d907ad58403 = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_346d1a6d2543ff78a4245d907ad58403
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_c051206dae59c3e983dd16226fcb0ff8);
#                     }
#                 map_c051206dae59c3e983dd16226fcb0ff8.on(&#x27;click&#x27;, latLngPop);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_c051206dae59c3e983dd16226fcb0ff8);
#
#
#             map_c051206dae59c3e983dd16226fcb0ff8.fitBounds(
#                 [[53.40433052645946, -2.9162212573496853], [53.40433052645946, -2.9162212573496853]],
#                 {&quot;maxZoom&quot;: 10}
#             );
#
#
#             var tile_layer_e73b5eae5e0a2c231b437bed36a41954 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-atanilsont/maps/2331c3d9276fc2a284c0695ca9758d3f-1b8c34649e4b5c9db95cce75dc6d10fa/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1.0,
# }
#
#             );
#
#
#             tile_layer_e73b5eae5e0a2c231b437bed36a41954.addTo(map_c051206dae59c3e983dd16226fcb0ff8);
#
#
#             var tile_layer_69de9706d2715168163accede3b9e0b7 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-atanilsont/maps/de9fb72c6e9f2695a0f1680927da82ee-1d3ac29babe568723c4fd089898ffddc/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1.0,
# }
#
#             );
#
#
#             tile_layer_69de9706d2715168163accede3b9e0b7.addTo(map_c051206dae59c3e983dd16226fcb0ff8);
#
#
#             var layer_control_9d7f8fc1d36eb19016ee6fe41787d65

# %% [markdown]
# # Exporting Image to google drive

# %%
def export_image(image, filename, region, folder):
    task = ee.batch.Export.image.toDrive(
        image=image,
        driveFolder = folder,
        scale=10,
        region=region.geometry(),
        description=filename,
        fileFormat="GeoTIFF",
        crs="EPSG:4326",
        maxPixels=900000000
    )
    task.start()
    return task

# %%
folder = "Colab Notebooks"
task = export_image(image1, "Norfolk20250711", region, folder)

# %%
task.status()
# Out:
# {'state': 'COMPLETED',
#  'description': 'Norfolk20250711',
#  'priority': 100,
#  'creation_timestamp_ms': 1752593828099,
#  'update_timestamp_ms': 1752594388689,
#  'start_timestamp_ms': 1752593831862,
#  'task_type': 'EXPORT_IMAGE',
#  'destination_uris': ['https://drive.google.com/#folders/17B3GdLsqMWcmnhuAZCbmUrYPu2lyfqod'],
#  'attempt': 1,
#  'batch_eecu_usage_seconds': 483.80914306640625,
#  'id': 'K53F4U3KFE3L6EZYW3EDMGWT',
#  'name': 'projects/ee-atanilsont/operations/K53F4U3KFE3L6EZYW3EDMGWT'}

# %% [markdown]
# # Cizualizing the downloaded imageMM

# %%
cwd = "./drive/My Drive/colab Notebooks/"
#tif_file = os.path.join(cwd, "{}.tif".format(shape_name))
tif_file = os.path.join(cwd, "Liverpool12072024.tif")

#https://drive.google.com/file/d/14lbn8Y5Mh894Alie-7NwxvyQbHAMZtQK/view?usp=drive_link
# Downoading from google drive
if not os.path.isfile(tif_file):
    #tif_file = "{}.tif".format(shape_name)
    tif_file = "Liverpool12072024.tif"
    # !gdown "17B3GdLsqMWcmnhuAZCbmUrYPu2lyfqod"
    print("Downloaded")

# %%
image = rio.open(tif_file)
boundary = geoboundary[geoboundary.shapeName == shape_name]

# Plot image and boundaries
fig, ax = plt.subplots(figsize=(15,15))
boundary.plot(facecolor="none", edgecolor="red", ax=ax)
show(image, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# # Generating 64x64 Tiels

# %%
## Function

# %%
def generate_tiles(image_file, output_file, area_str, size=64):
    """Genarates 64X64 polygon tiles.

    Args:
        image_file (str): Image file path (.tif)
        output_file
    """

    # Open the raser image using rasterio
    raster = rio.open(image_file)
    width, height = raster.shape

    # Create a dictionary which will conatin our 64Z64 px polygon tiles
    # Later convert this dict into GeoPandas DataFrame
    geo_dict = {"id":[],"geometry":[]}
    index = 0

    # Do a sliding windows across the raste image
    with tqdm(total=width*height) as pbar:
        for w in range(0, width, size):
            for h in range(0, height, size):
                # Create a Window of your disired size
                window = rio.windows.Window(h, w, size, size)

                # Get the georeferenced windowss bounds
                bbox = rio.windows.bounds(window, raster.transform)

                # Create a shapely geometry from the bounding box
                bbox = box(*bbox)

                # Create a unique id for each geometry
                uid = "{}-{}".format(area_str.lower().replace("","_"), index)

                # Update dictionary
                geo_dict["id"].append(uid)
                geo_dict["geometry"].append(bbox)

                index += 1
                pbar.update(size*size)

    # Cast dictionary as a GeoPandas DataFrame
    results = gpd.GeoDataFrame(pd.DataFrame(geo_dict))

    # Set CRS to EPSG: 4326
    results.crs = {"init":"epsg:4326"}

    # Save file as GeoJSON
    results.to_file(output_file, driver="GeoJSON")

    raster.close()
    return results

# %%
## Generating

# %%
output_file = os.path.join(cwd, "{}.geojson".format(shape_name))
tiles = generate_tiles(tif_file, output_file, shape_name, size=64)

print("Data dimensions: {}".format(tiles.shape))
tiles.head(3)
# Out:
#   0%|          | 0/3478704 [00:00<?, ?it/s]
# Data dimensions: (884, 2)
# /usr/local/lib/python3.11/dist-packages/pyproj/crs/crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#                       id                                           geometry
# 0  _l_i_v_e_r_p_o_o_l_-0  POLYGON ((-3.00307 53.46925, -3.00307 53.475, ...
# 1  _l_i_v_e_r_p_o_o_l_-1  POLYGON ((-2.99732 53.46925, -2.99732 53.475, ...
# 2  _l_i_v_e_r_p_o_o_l_-2  POLYGON ((-2.99157 53.46925, -2.99157 53.475, ...

# %% [markdown]
# # Visualizing 64x64 px Tiles and Images

# %%
image = rio.open(tif_file)
fig, ax = plt.subplots(figsize = (15,15))
tiles.plot(facecolor="none", edgecolor = "red", ax=ax)
show(image, ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# Deleating tiles outslide the region

# %%
image = rio.open(tif_file)

tiles = gpd.sjoin(tiles, boundary, predicate="within")

fig, ax = plt.subplots(figsize=(15,15))
tiles.plot(facecolor="none", edgecolor="red", ax=ax)
show(image, ax=ax)
# Out:
# /tmp/ipython-input-176-1846489946.py:3: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: +init=epsg:4326 +type=crs
# Right CRS: EPSG:4326
#
#   tiles = gpd.sjoin(tiles, boundary, predicate="within")
# <Axes: >

# %% [markdown]
# # Vizualizing a single cropped image

# %%
def show_crop(image, shape, title=""):
    """
    Crop image base on the polyfon shape
    Reference: https://rasterio.readthedocs.io/en/latest/api/rasterio.mask.html#rasterio.mask.mask
    """

    with rio.open(image) as src:
        out_image, out_transform = rio.mask.mask(src, shape, crop=True)
        # Crop out black (zero) boarder
        _, x_nonzero, y_nonzero = np.nonzero(out_image)

        out_image = out_image[
            :,
            np.min(x_nonzero):np.max(x_nonzero),
            np.min(y_nonzero):np.max(y_nonzero)
        ]
        # Visualize image
        show(out_image, title=title)

# %%
def get_crop(image, shape, title=""):
    """
    Crop image base on the polyfon shape
    Reference: https://rasterio.readthedocs.io/en/latest/api/rasterio.mask.html#rasterio.mask.mask
    """

    with rio.open(image) as src:
        out_image, out_transform = rio.mask.mask(src, shape, crop=True)
        # Crop out black (zero) boarder
        _, x_nonzero, y_nonzero = np.nonzero(out_image)

        out_image = out_image[
            :,
            np.min(x_nonzero):np.max(x_nonzero),
            np.min(y_nonzero):np.max(y_nonzero)
        ]
        # Visualize image
        return out_image

# %%
show_crop(tif_file, [tiles.iloc[4]["geometry"]])

# %%
get_crop(tif_file, [tiles.iloc[4]["geometry"]]).shape
# Out:
# (3, 63, 63)

# %% [markdown]
# # Genating the landcover map

# %%
# LULC Classes
classes = [
    "AnnualCrop",
    "Forest",
    "HerbaceousVegetation",
    "Highway",
    "Industrial",
    "Pasture",
    "PermanentCrop",
    "Residential",
    "River",
    "SeaLake"
]

# %% [markdown]
# # Loading the model

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
#model_file = cwd+"/models/model.pth"
#model_file = "model_1.pth"

#if not os.path.isfile(model_file):
#    model_file = "model.pth"
#    !gdown "--ID--"

# %%
from pathlib import Path
from torchvision.models import resnet50

MODEL_PATH = Path("models")
MODEL_PATH.mkdir(parents=True, exist_ok=True)

MODEL_NAME = "best_model_2.pth"
MODEL_SAVE_PATH = MODEL_PATH/MODEL_NAME

# %%
path_drive = "./drive/MyDrive/Colab Notebooks/models/best_model_2.pth"

# %%
from torch import nn

model_2 = resnet50(weights=None)

model_2.fc = torch.nn.Linear(in_features=model_2.fc.in_features, out_features=len(classes))

model_2.load_state_dict(torch.load(f=path_drive, map_location=device))
model_2 = model_2.to(device)

# %%
model_2 = model_2.to("cpu")

# %%
#model_2.load_state_dict(torch.load(model_file, map_location=device))
model_2.eval()

print("Model file {} sucessfully loaded.".format(MODEL_SAVE_PATH))
# Out:
# Model file models/best_model_2.pth sucessfully loaded.

# %%
transform = transforms.Compose([
    transforms.Resize((64,64)),
    #transforms.RandomHorizontalFlip(),
    #transforms.RandomRotation(10),
    transforms.ToTensor(),
    #transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
show_crop(tif_file, [tiles.iloc[5]["geometry"]])

# %%
get_crop(tif_file, [tiles.iloc[4]["geometry"]]).shape
# Out:
# (3, 63, 63)

# %%
#transform(get_crop(tif_file, [tiles.iloc[4]["geometry"]]))

# %% [markdown]
# # Prediction and LC Generation

# %%
def predict_crop(image, shape, classes, model, show=False):
    """
    Generate prediciton
    """
    with rio.open(image) as src:
        # Crop source image using polyhon shape
        ## https://rasterio.readthedocs.io/en/latest/api/rasterio.mask.html#rasterio.mask.mask

        out_image, out_transform = rio.mask.mask(src, shape, crop=True)

        # Crop out black (zero) border
        _, x_nonzero, y_nonzero = np.nonzero(out_image)
        out_image = out_image[
            :,
            np.min(x_nonzero):np.max(x_nonzero),
            np.min(y_nonzero):np.max(y_nonzero)
        ]

        # Get the metadata of the source image and update it
        # with the width, height, and transfor, of the cropped image
        out_meta = src.meta
        out_meta.update({
            "driver": "GTiff",
            "height": out_image.shape[1],
            "width": out_image.shape[2],
            "transform": out_transform
        })

        # Save the cropped image as a temporatry TIFF file.
        temp_tif = "temp.tif"
        with rio.open(temp_tif, "w", **out_meta) as dest:
            dest.write(out_image)

        # Open the cropped image and genrated prediction
        # Using the model
        image = Image.open(temp_tif)
        input = transform(image)
        output = model(input.unsqueeze(0))
        _, pred = torch.max(output, 1)
        label = str(classes[int(pred[0])])

        if show:
            out_image.show(title=label)

        return label

    return None

# %% [markdown]
# Iterating iver the 64x64 pile and genarating model predictions for the corresponding cropped image. Note htat we are overwritting each temporary TIFF file ro save storage space

# %%
#
labels = [] # Stor prediction
#for index in tqdm(range(len(tiles)), total=len(tiles)):
for index in tqdm(range(len(tiles)), total=len(tiles)):
  try:
    label = predict_crop(tif_file, [tiles.iloc[index]['geometry']], classes, model_2)
    labels.append(label)
  except:
    labels.append("Error")
    continue

tiles['pred'] = labels

#Save prediction
filepath = os.path.join(cwd, "{}_preds.geojson".format(shape_name))
tiles.to_file(filepath, driver="GeoJSON")

tiles.head(3)
# Out:
#   0%|          | 0/390 [00:00<?, ?it/s]
#                         id                                           geometry  \
# 43  _l_i_v_e_r_p_o_o_l_-43  POLYGON ((-2.95133 53.4635, -2.95133 53.46925,...
# 44  _l_i_v_e_r_p_o_o_l_-44  POLYGON ((-2.94558 53.4635, -2.94558 53.46925,...
# 45  _l_i_v_e_r_p_o_o_l_-45  POLYGON ((-2.93983 53.4635, -2.93983 53.46925,...
#
#     index_right  shapeName shapeISO                  shapeID shapeGroup  \
# 43           67  Liverpool           12218062B18232951435959        GBR
# 44           67  Liverpool           12218062B18232951435959        GBR
# 45           67  Liverpool           12218062B18232951435959        GBR
#
#    shapeType        pred
# 43      ADM3  AnnualCrop
# 44      ADM3  AnnualCrop
# 45      ADM3  AnnualCrop

# %%
len(tiles[tiles["pred"]=="Error"]), len(tiles)
# Out:
# (10, 390)

# %%
# We map each class to a corresponding color
colors = {
  'AnnualCrop' : 'lightgreen',
  'Forest' : 'forestgreen',
  'HerbaceousVegetation' : 'yellowgreen',
  'Highway' : 'gray',
  'Industrial' : 'red',
  'Pasture' : 'mediumseagreen',
  'PermanentCrop' : 'chartreuse',
  'Residential' : 'magenta',
  'River' : 'dodgerblue',
  'SeaLake' : 'blue',
  'Error' : 'black'
}
tiles['color'] = tiles["pred"].apply(
  lambda x: cl.to_hex(colors.get(x))
)
tiles.head(2)
# Out:
#                         id                                           geometry  \
# 43  _l_i_v_e_r_p_o_o_l_-43  POLYGON ((-2.95133 53.4635, -2.95133 53.46925,...
# 44  _l_i_v_e_r_p_o_o_l_-44  POLYGON ((-2.94558 53.4635, -2.94558 53.46925,...
#
#     index_right  shapeName shapeISO                  shapeID shapeGroup  \
# 43           67  Liverpool           12218062B18232951435959        GBR
# 44           67  Liverpool           12218062B18232951435959        GBR
#
#    shapeType        pred    color
# 43      ADM3  AnnualCrop  #90ee90
# 44      ADM3  AnnualCrop  #90ee90

# %%
# Instantiate map centered on the centroid
map = folium.Map(location=[centroid[1], centroid[0]], zoom_start=10)

# Add Google Satellite basemap
folium.TileLayer(
      tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
      attr = 'Google',
      name = 'Google Satellite',
      overlay = True,
      control = True
).add_to(map)

# Add LULC Map with legend
legend_txt = '<span style="color: {col};">{txt}</span>'
for label, color in colors.items():

  # Specify the legend color
  name = legend_txt.format(txt=label, col=color)
  feat_group = folium.FeatureGroup(name=name)

  # Add GeoJSON to feature group
  subtiles = tiles[tiles.pred==label]
  if len(subtiles) > 0:
    folium.GeoJson(
        subtiles,
        style_function=lambda feature: {
          'fillColor': feature['properties']['color'],
          'color': 'black',
          'weight': 1,
          'fillOpacity': 0.5,
        },
        name='LULC Map'
    ).add_to(feat_group)
    map.add_child(feat_group)

folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc6e10b5ebd342eea4c9875d18e5e612 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc6e10b5ebd342eea4c9875d18e5e612&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc6e10b5ebd342eea4c9875d18e5e612 = L.map(
#                 &quot;map_cc6e10b5ebd342eea4c9875d18e5e612&quot;,
#                 {
#                     center: [53.40433052645946, -2.9162212573496853],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73367da08f7925a2518cb36a4bd6ef7a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73367da08f7925a2518cb36a4bd6ef7a.addTo(map_cc6e10b5ebd342eea4c9875d18e5e612);
#
#
#             var tile_layer_75bf1f7cf01c57d84d346d82db5a58cd = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75bf1f7cf01c57d84d346d82db5a58cd.addTo(map_cc6e10b5ebd342eea4c9875d18e5e612);
#
#
#             var feature_group_50618439e0696a21d0d39946fc7f4cad = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_f4511e33545bfd2ae8b5a888dfb4def4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#90ee90&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f4511e33545bfd2ae8b5a888dfb4def4_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_f4511e33545bfd2ae8b5a888dfb4def4 = L.geoJson(null, {
#                 onEachFeature: geo_json_f4511e33545bfd2ae8b5a888dfb4def4_onEachFeature,
#
#                 style: geo_json_f4511e33545bfd2ae8b5a888dfb4def4_styler,
#             ...{
# }
#         });
#
#         function geo_json_f4511e33545bfd2ae8b5a888dfb4def4_add (data) {
#             geo_json_f4511e33545bfd2ae8b5a888dfb4def4
#                 .addData(data);
#         }
#             geo_json_f4511e33545bfd2ae8b5a888dfb4def4_add({&quot;bbox&quot;: [-3.0030679948115604, 53.33127161913617, -2.847839113715707, 53.469252846776925], &quot;features&quot;: [{&quot;bbox&quot;: [-2.9570742522646407, 53.463503628958556, -2.951325034446276, 53.469252846776925], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-2.951325034446276, 53.463503628958556], [-2.951325034446276, 53.469252846776925], [-2.9570742522646407, 53.469252846776925], [-2.9570742522646407, 53.463503628958556], [-2.951325034446276, 53.463503628958556]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;43&quot;, &quot;properties&quot;: {&quot;color&quot;: &quot;#90ee90&quot;, &quot;id&quot;: &quot;_l_i_v_e_r_p_o_o_l_-43&quot;, &quot;index_right&quot;: 67, &quot;pred&quot;: &quot;AnnualCrop&quot;, &quot;shapeGroup&quot;: &quot;GBR&quot;, &quot;shapeID&quot;: &quot;12218062B18232951435959&quot;, &quot;shapeISO&quot;: &quot;&quot;, &quot;shapeName&quot;: &quot;Liverpool&quot;, &quot;shapeType&quot;: &quot;ADM3&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-2.951325034446276, 53.463503628958556, -2.945575816627911, 53.469252846776925], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-2.945575816627911, 53.463503628958556], [-2.945575816627911, 53.469252846776925], [-2.951325034446276, 53.469252846776925], [-2.951325034446276, 53.463503628958556], [-2.945575816627911, 53.463503628958556]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;44&quot;, &quot;properties&quot;: {&quot;color&quot;: &quot;#90ee90&quot;, &quot;id&quot;: &quot;_l_i_v_e_r_p_o_o_l_-44&quot;, &quot;index_right&quot;: 67, &quot;pred&quot;: &quot;AnnualCrop&quot;, &quot;shapeGroup&quot;: &quot;GBR&quot;, &quot;shapeID&quot;: &quot;12218062B18232951435959&quot;, &quot;shapeISO&quot;: &quot;&quot;, &quot;shapeName&quot;: &quot;Liverpool&quot;, &quot;shapeType&quot;: &quot;ADM3&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-2.945575816627911, 53.463503628958556, -2.939826598809546, 53.469252846776925], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-2.939826598809546, 53.463503628958556], [-2.939826598809546, 53.469252846776925
